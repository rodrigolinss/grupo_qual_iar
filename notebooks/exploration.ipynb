# %%
import pandas as pd
# Out:
# C:\Users\vitor.franco\AppData\Local\Temp\ipykernel_28972\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\vitor.franco\\Desktop\\brasilia-air-quality\\data\\bronze\\monitorar.csv")

# %%
df.head()
# Out:
#     station_id station_name  latitude  longitude pollutant  value   unit  \
# 0  cras_fercal  CRAS Fercal  -15.7023   -47.8008      pm25  11.56  µg/m³
# 1  cras_fercal  CRAS Fercal  -15.7023   -47.8008      pm10  16.22  µg/m³
# 2  cras_fercal  CRAS Fercal  -15.7023   -47.8008        o3  16.58  µg/m³
# 3  cras_fercal  CRAS Fercal  -15.7023   -47.8008       no2   9.27  µg/m³
# 4  cras_fercal  CRAS Fercal  -15.7023   -47.8008       so2   1.78  µg/m³
#
#    avg_period_minutes         datetime_utc       datetime_local  \
# 0                  60  2000-01-01T00:00:00  2000-01-01T00:00:00
# 1                  60  2000-01-01T00:00:00  2000-01-01T00:00:00
# 2                  60  2000-01-01T00:00:00  2000-01-01T00:00:00
# 3                  60  2000-01-01T00:00:00  2000-01-01T00:00:00
# 4                  60  2000-01-01T00:00:00  2000-01-01T00:00:00
#
#                             source_url source_agency  \
# 0  https://monitorar.mma.gov.br/painel           MMA
# ...
